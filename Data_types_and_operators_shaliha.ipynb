# %% [markdown]
# <a href="https://colab.research.google.com/github/shaliha223/DSA_class_activities/blob/main/Data_types_and_operators_shaliha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(5+5.0))
# Out:
# <class 'float'>

# %%
str(5)+"apples"
# Out:
# '5apples'

# %%
print(len("Python Rocks!"))
# Out:
# 13

# %%
a, b = 15,4
print("a+b=",a+b)
print("a-b=",a-b)
print("a*b=",a*b)
print("a/b=",a/b)
# Out:
# a+b= 19
# a-b= 11
# a*b= 60
# a/b= 3.75

# %%
print(15//4)
# Out:
# 3

# %%
print(3**4)
# Out:
# 81

# %%
a = 10+2*5
print(a)#First multiply 2 and 5, then multiply the answer by 10.
# Out:
# 20

# %%
print(7%3==1)
# Out:
# True

# %%
a = 3**2+1
type(a)
# Out:
# int

# %%
print(8//3==2)
# Out:
# True

# %%
print(len("car")==3)
# Out:
# True

# %%
print("Python"!="python")
# Out:
# True

# %%
print(type("10"))
print(type(10))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(None==False)
# Out:
# False

# %%
print(10>=10)
# Out:
# True

# %%
a = 15
print(10<a and a<20)
# Out:
# True

# %%
a = len("1234567890")
print(a%2==0)#checking length is even
# Out:
# True

# %%
a = "shaliha223@gmail.com"
print("@" in a and "." in a)
# Out:
# True

# %%
a = type(len("hello"))
print(a is int)
# Out:
# True
